# %% [markdown]
# # Pneumonia Diagnosis using Lungs' XRays

# %%
import pandas as pd 
import cv2                 
import numpy as np         
import os                  
from random import shuffle
from tqdm import tqdm  
import scipy
import skimage
from skimage.transform import resize
print(os.listdir("../chest_xray"))
# Out:
# ['val', 'train', '.DS_Store', 'test', '.ipynb_checkpoints']

# %%
print(os.listdir("../chest_xray/train/"))
# Out:
# ['.DS_Store', 'PNEUMONIA', 'NORMAL']

# %%
TRAIN_DIR = "../chest_xray/train/"
TEST_DIR =  "../chest_xray/test/"

# %% [markdown]
# **Preprocessing**

# %%
def get_label(Dir):
    for nextdir in os.listdir(Dir):
        if not nextdir.startswith('.'):
            if nextdir in ['NORMAL']:
                label = 0
            elif nextdir in ['PNEUMONIA']:
                label = 1
            else:
                label = 2
    return nextdir, label

# %%
def preprocessing_data(Dir):
    X = []
    y = []
    
    for nextdir in os.listdir(Dir):
        nextdir, label = get_label(Dir)
        temp = Dir + nextdir
        
        for image_filename in tqdm(os.listdir(temp)):
            path = os.path.join(temp + '/' , image_filename)
            img = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
            if img is not None:
                img = skimage.transform.resize(img, (150, 150, 3))
                img = np.asarray(img)
                X.append(img)
                y.append(label)
            
    X = np.asarray(X)
    y = np.asarray(y)
    
    return X,y

# %%
# X_train, y_train = preprocessing_data(TRAIN_DIR)

# %%
def get_data(Dir):
    X = []
    y = []
    for nextDir in os.listdir(Dir):
        if not nextDir.startswith('.'):
            if nextDir in ['NORMAL']:
                label = 0
            elif nextDir in ['PNEUMONIA']:
                label = 1
            else:
                label = 2
                
            temp = Dir + nextDir
                
            for file in tqdm(os.listdir(temp)):
                img = cv2.imread(temp + '/' + file)
                if img is not None:
                    img = skimage.transform.resize(img, (150, 150, 3))
                    #img_file = scipy.misc.imresize(arr=img_file, size=(150, 150, 3))
                    img = np.asarray(img)
                    X.append(img)
                    y.append(label)
                    
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
X_train, y_train = get_data(TRAIN_DIR)
# Out:
#   0%|          | 0/3876 [00:00<?, ?it/s]/home/martin/anaconda3/envs/tfgpu/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/martin/anaconda3/envs/tfgpu/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 100%|██████████| 3876/3876 [01:32<00:00, 42.03it/s]
# 100%|██████████| 1342/1342 [01:19<00:00, 16.81it/s]

# %%
X_test , y_test = get_data(TEST_DIR)
# Out:
# 100%|██████████| 390/390 [00:07<00:00, 53.21it/s]
# 100%|██████████| 234/234 [00:14<00:00, 11.44it/s]

# %%
print(X_train.shape,'\n',X_test.shape)
# Out:
# (5216, 150, 150, 3)
#  (624, 150, 150, 3)

# %%
print(y_train.shape,'\n',y_test.shape)
# Out:
# (5216,)
#  (624,)

# %%
from keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **The arrays are not normalized because they have already been provided in the necessary format.**

# %%
print(y_train.shape,'\n',y_test.shape)
# Out:
# (5216, 2)
#  (624, 2)

# %%
Pimages = os.listdir(TRAIN_DIR + "PNEUMONIA")
Nimages = os.listdir(TRAIN_DIR + "NORMAL")

# %%
import matplotlib.pyplot as plt
def plotter(i):
    imagep1 = cv2.imread(TRAIN_DIR+"PNEUMONIA/"+Pimages[i])
    imagep1 = skimage.transform.resize(imagep1, (150, 150, 3) , mode = 'reflect')
    imagen1 = cv2.imread(TRAIN_DIR+"NORMAL/"+Nimages[i])
    imagen1 = skimage.transform.resize(imagen1, (150, 150, 3))
    pair = np.concatenate((imagen1, imagep1), axis=1)
    print("(Left) - No Pneumonia Vs (Right) - Pneumonia")
    print("-----------------------------------------------------------------------------------------------------------------------------------")
    plt.figure(figsize=(10,5))
    plt.imshow(pair)
    plt.show()
for i in range(0,5):
    plotter(i)
# Out:
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# -----------------------------------------------------------------------------------------------------------------------------------
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# -----------------------------------------------------------------------------------------------------------------------------------
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# -----------------------------------------------------------------------------------------------------------------------------------
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# -----------------------------------------------------------------------------------------------------------------------------------
# (Left) - No Pneumonia Vs (Right) - Pneumonia
# -----------------------------------------------------------------------------------------------------------------------------------

# %%
import seaborn as sns
count = y_train.sum(axis = 0)
sns.countplot(x = count)

# %% [markdown]
# **The classes are imbalanced therefore validation accuracy won't be a good metric to analyze the model performance , We will also have to take precision , recall and confusion matrix into account.**

# %%
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
# Out:
# /home/martin/anaconda3/envs/tfgpu/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# **Callbacks to reduce learning rate timely after monitoring a quantity.**

# %%
filepath="weights_1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# **Making checkpoints timely to check and save the best model performance till last and also avoiding further validation accuracy drop due to overfitting.**

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD , RMSprop
from keras.layers import Conv2D , BatchNormalization
from keras.layers import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
X_train=X_train.reshape(5216,3,150,150)
X_test=X_test.reshape(624,3,150,150)

# %% [markdown]
# ### Tried different model architectures , the best I could achieve was 83.75 % validation accuracy without any pre-trained CNN models. The architecture is different from the best and could give 83.01 %  . But again our main criteria is not accuracy but the precision and recall.

# %% [markdown]
# ### Other Hyperparameters like learning rates, epochs, batch size , no. of filters , activation function have been tuned repeatedly to achieve better results.

# %%
def swish_activation(x):
    return (K.sigmoid(x) * x)

model = Sequential()
model.add(Conv2D(16, (3, 3), activation='relu', padding="same", input_shape=(3,150,150)))
model.add(Conv2D(16, (3, 3), padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), activation='relu', padding="same", input_shape=(3,150,150)))
model.add(Conv2D(32, (3, 3), padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding="same"))
model.add(Conv2D(64, (3, 3), padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(96, (3, 3), dilation_rate=(2, 2), activation='relu', padding="same"))
model.add(Conv2D(96, (3, 3), padding="valid", activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), dilation_rate=(2, 2), activation='relu', padding="same"))
model.add(Conv2D(128, (3, 3), padding="valid", activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(64, activation=swish_activation))
model.add(Dropout(0.4))
model.add(Dense(2 , activation='sigmoid'))

model.compile(loss='binary_crossentropy',
                  optimizer=RMSprop(lr=0.00005),
                  metrics=['accuracy'])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 150, 150)      448
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 150, 150)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 75, 75)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 75, 75)        4640
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 75, 75)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 37, 37)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 37, 37)        18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 37, 37)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 18, 18)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 96, 18, 18)        55392
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 96, 16, 16)        83040
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 96, 8, 8)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 8, 8)         110720
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 6, 6)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 3, 3)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                73792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 542,738
# Trainable params: 542,738
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 256
epochs = 32 #6

# %%
history = model.fit(X_train, y_train, validation_data = (X_test , y_test) ,callbacks=[lr_reduce,checkpoint] ,
          epochs=epochs)
# Out:
# Train on 5216 samples, validate on 624 samples
# Epoch 1/32
# 5216/5216 [==============================] - 7s 1ms/step - loss: 0.5791 - acc: 0.7400 - val_loss: 0.7320 - val_acc: 0.6250
#
# Epoch 00001: val_acc improved from -inf to 0.62500, saving model to weights_1.hdf5
# Epoch 2/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.4305 - acc: 0.7994 - val_loss: 0.4834 - val_acc: 0.7508
#
# Epoch 00002: val_acc improved from 0.62500 to 0.75080, saving model to weights_1.hdf5
# Epoch 3/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.3422 - acc: 0.8486 - val_loss: 0.4550 - val_acc: 0.7732
#
# Epoch 00003: val_acc improved from 0.75080 to 0.77324, saving model to weights_1.hdf5
# Epoch 4/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.3015 - acc: 0.8719 - val_loss: 0.5045 - val_acc: 0.7764
#
# Epoch 00004: val_acc improved from 0.77324 to 0.77644, saving model to weights_1.hdf5
# Epoch 5/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.2631 - acc: 0.8900 - val_loss: 0.4479 - val_acc: 0.8069
#
# Epoch 00005: val_acc improved from 0.77644 to 0.80689, saving model to weights_1.hdf5
# Epoch 6/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.2322 - acc: 0.9040 - val_loss: 0.6621 - val_acc: 0.7396
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 00006: val_acc did not improve from 0.80689
# Epoch 7/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1992 - acc: 0.9201 - val_loss: 0.6078 - val_acc: 0.7572
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-07.
#
# Epoch 00007: val_acc did not improve from 0.80689
# Epoch 8/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1912 - acc: 0.9215 - val_loss: 0.5972 - val_acc: 0.7580
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 4.999999987376214e-08.
#
# Epoch 00008: val_acc did not improve from 0.80689
# Epoch 9/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1967 - acc: 0.9204 - val_loss: 0.5963 - val_acc: 0.7596
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 5.000000058430488e-09.
#
# Epoch 00009: val_acc did not improve from 0.80689
# Epoch 10/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1912 - acc: 0.9226 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.999999969612646e-10.
#
# Epoch 00010: val_acc did not improve from 0.80689
# Epoch 11/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1921 - acc: 0.9225 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.999999858590343e-11.
#
# Epoch 00011: val_acc did not improve from 0.80689
# Epoch 12/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1918 - acc: 0.9238 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.999999719812465e-12.
#
# Epoch 00012: val_acc did not improve from 0.80689
# Epoch 13/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1905 - acc: 0.9224 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.999999546340118e-13.
#
# Epoch 00013: val_acc did not improve from 0.80689
# Epoch 14/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1905 - acc: 0.9203 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.9999994379199e-14.
#
# Epoch 00014: val_acc did not improve from 0.80689
# Epoch 15/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1928 - acc: 0.9230 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.999999573445172e-15.
#
# Epoch 00015: val_acc did not improve from 0.80689
# Epoch 16/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1923 - acc: 0.9208 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.999999488741877e-16.
#
# Epoch 00016: val_acc did not improve from 0.80689
# Epoch 17/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1944 - acc: 0.9220 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.999999488741877e-17.
#
# Epoch 00017: val_acc did not improve from 0.80689
# Epoch 18/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1938 - acc: 0.9232 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.999999422567428e-18.
#
# Epoch 00018: val_acc did not improve from 0.80689
# Epoch 19/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1909 - acc: 0.9225 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 4.999999505285489e-19.
#
# Epoch 00019: val_acc did not improve from 0.80689
# Epoch 20/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1919 - acc: 0.9220 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.9999997120806425e-20.
#
# Epoch 00020: val_acc did not improve from 0.80689
# Epoch 21/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1920 - acc: 0.9219 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.999999841327613e-21.
#
# Epoch 00021: val_acc did not improve from 0.80689
# Epoch 22/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1905 - acc: 0.9210 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.999999841327613e-22.
#
# Epoch 00022: val_acc did not improve from 0.80689
# Epoch 23/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1927 - acc: 0.9220 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.9999998413276127e-23.
#
# Epoch 00023: val_acc did not improve from 0.80689
# Epoch 24/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1923 - acc: 0.9225 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.999999841327613e-24.
#
# Epoch 00024: val_acc did not improve from 0.80689
# Epoch 25/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1926 - acc: 0.9220 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.999999999099794e-25.
#
# Epoch 00025: val_acc did not improve from 0.80689
# Epoch 26/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1924 - acc: 0.9216 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 5.000000097707407e-26.
#
# Epoch 00026: val_acc did not improve from 0.80689
# Epoch 27/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1927 - acc: 0.9219 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 5.000000097707407e-27.
#
# Epoch 00027: val_acc did not improve from 0.80689
# Epoch 28/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1939 - acc: 0.9215 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.999999943633012e-28.
#
# Epoch 00028: val_acc did not improve from 0.80689
# Epoch 29/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1929 - acc: 0.9211 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 5.000000136226006e-29.
#
# Epoch 00029: val_acc did not improve from 0.80689
# Epoch 30/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1953 - acc: 0.9211 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 5.000000015855384e-30.
#
# Epoch 00030: val_acc did not improve from 0.80689
# Epoch 31/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1927 - acc: 0.9210 - val_loss: 0.5960 - val_acc: 0.7596
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 5.000000015855384e-31.
#
# Epoch 00031: val_acc did not improve from 0.80689
# Epoch 32/32
# 5216/5216 [==============================] - 6s 1ms/step - loss: 0.1917 - acc: 0.9226 - val_loss: 0.5960 - val_acc: 0.7596
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 5.000000015855385e-32.
#
# Epoch 00032: val_acc did not improve from 0.80689

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **The model will try to overfit itself but rather save it prior going to the next epoch using necessary callbacks.**

# %% [markdown]
# **For better performance use exponential decaying learning rate and specify steps_per_epoch**

# %%
from sklearn.metrics import confusion_matrix
pred = model.predict(X_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

# %% [markdown]
# **Using mlxtend library for quick implementation of confusion matrix.**

# %%
CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()

# %% [markdown]
# **Now, a model not good for validation accuracy might be actually good for precision or recall. So better tune according to the metric or your need.**

# %%
#precision = True Positive / (True Positive + False Positive)

380 / (380 + 141)
# Out:
# 0.7293666026871402

# %%
#recall = True Positive / (True Positive + False Negative)

380 / (380 + 10)
# Out:
# 0.9743589743589743

# %% [markdown]
# ### Here , recall is most significant quantity even more than accuracy and precision.

# %% [markdown]
# ###  Since we are having unequal number of people in both the classes , therefore we can't take accuracy as an alone metric to calculate model efficieny .

# %% [markdown]
# #### precision = True Positive / (True Positive + False Positive)
#
# #### recall = True Positive / (True Positive + False Negative)

# %% [markdown]
# ### Also precision can't be taken as alone metric and has less significance than recall in this particular dataset because we have to minimize false negative and that is in the denominator and thus finally increasing 'Recall' .

# %% [markdown]
# ### False negative has to be intuitively minimized because we can't falsely diagnose a patient of pneumonia which is our major concern . That is why we are making this model . To reduce the mistakes done by doctors accidentally .

# %% [markdown]
# **-------------Data Science has always been much about context and intuition.--------------------------**
